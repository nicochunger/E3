# %% [markdown]
# # Atomos (Guia 5)
#
# Nicolas Unger

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Son las energias del estado 2p(2) y 3p(2) para iones isoelectronicos del Helio
# Calculadas con hf.f (Fischer)
# H, He, Li, Be, B, C, N, O, F, Ne, Na, Mg
energia_2p2 = np.array([-0.11588, -0.7014, -1.7872, -3.3732, -5.4590, -8.0450, -11.13094, -14.7168, -18.8028,
                    -23.3887, -28.4746, -34.0606])
energia_3p2 = np.array([-0.0554, -0.3241, -0.8150, -1.5281, -2.4634, -3.6210, -5.0008, -6.6028, -8.4270, -10.4734,
                       -12.7421, -15.2330])
x = range(1,len(energia)+1)

plt.plot(x,energia_2p2,'r-',label="2p(2)")
plt.plot(x,energia_2p2,'k.')
plt.plot(x,energia_3p2,'b-',label="3p(2)")
plt.plot(x,energia_3p2,'k.')
plt.legend()
plt.title("Energias del estado np(2) para iones isoelectronicos al Helio")
plt.xlabel("Z del atomo")
plt.ylabel("Energia (a.u.)")
plt.show()
