# %% [markdown]
# # Trabajo Final de Estructura 3
#
# ## Resolver la ecuacion de Schrödinger con el metodo variacional usando como base a polinomios de Chebychev
#
# Nicolas Unger

# %%
from numpy import *
import sympy as sp
from matplotlib.pyplot import plot, xlabel, ylabel, title, xlim, ylim, legend, show

# Estática
#sp.init_printing()
#%matplotlib inline

# %%
x = sp.Symbol("x")
n = sp.Symbol("n",integer=True)

# %%
# Armo los polinomios de Chebychev usando la regla de recurrencia
def cheby(n,x):
    if n == 0:
        return 1
    elif n == 1:
        return x
    else:
        return 2*x*cheby(n-1,x) - cheby(n-2,x)

# %%
# Test para ver si me dan bien
xmin = -1
xmax = 1
npts = 300
rango = linspace(xmin,xmax,npts)

nfunc = 5
T = zeros([npts, nfunc])

for j in range(nfunc):
    for i in range(npts):
        T[i,j] = cheby(j,rango[i])

for j in range(nfunc):
    plot(rango,T[:,j],label="T"+str(j))
    
title("Primeros {} polinomios de Chebychev".format(nfunc))
xlabel("x")
ylabel("y")
legend()
show()

# %% [markdown]
# ## Uso el metodo variacional

# %%
from scipy.linalg import eigh

# %%
nbase = 1 # Cantidad de elementos en la base
Z = 1 # Numero atomico
l = 0 # Nuero cuantico l
S = zeros((nbase,nbase)) # Matriz de Overlap
H = zeros((nbase,nbase)) # Matriz del Hamiltoniano
Ci = zeros((nbase))# Datos Iniciales para variacional

# %%
# Defino los primeros polinomios de forma anailitca
T0 = cheby(0,x)*sp.exp(-0.5*x)
T1 = cheby(1,x)*sp.exp(-x)
T2 = cheby(2,x)*sp.exp(-x)
T3 = cheby(3,x)*sp.exp(-x)
T4 = cheby(4,x)*sp.exp(-x)
peso = 1/sp.sqrt(1-x**2)

# %%
# Matriz de Overlap <phi_a|phi_b>

def overlap(a, b):
    """ Genera la matriz de overlap de <phi_a|phi_b>. """
    assert type(a) == int and type(b) == int, "a y b tienen que ser numeros enteros."
    assert a >= 0 and b >=0, "a y b tienen que ser numeros mayores o iguales a 0."
    Ta = cheby(a,x)*sp.exp(-x)
    Tb = cheby(b,x)*sp.exp(-x)
    resultado = sp.integrate(Ta*Tb*x**2, (x,0,sp.oo)) * 4*sp.pi
    return resultado.evalf()

for i in range(nbase):
    for j in range(i,nbase):
        S[i,j] = overlap(i,j)
        S[j,i] = S[i,j]
        
S
# Out:
# array([[ 3.14159265]])

# %%
# Hamiltoniano

def Tkin(a, b):
    Ta = cheby(a,x)*sp.exp(-x)
    Tb = cheby(b,x)*sp.exp(-x)
    resultado = -(1/2) * sp.integrate(x**2 * Ta * sp.diff(Tb,x,x), (x,0,sp.oo)) * 4*sp.pi
    return resultado.evalf()

def Vpot(a, b):
    Ta = cheby(a,x)*sp.exp(-x)
    Tb = cheby(b,x)*sp.exp(-x)
    resultado = sp.integrate(x**2 * Ta * (-Z/x) * Tb, (x,0,sp.oo)) * 4*sp.pi
    return resultado.evalf()

for i in range(nbase):
    for j in range(i,nbase):
        H[i,j] = Tkin(i,j) + Vpot(i,j)
        H[j,i] = H[i,j]
        
H
# Out:
# array([[-3.14159265]])

# %%
Energia,coef = eigh(H,S,type=1)
Ci = coef[:,0]
Ci
# Out:
# array([ 0.56418958])

# %%
Energia
# Out:
# array([-1.])

# %%
def psi(Ci,rango):
    sum = 0.0
    for i in range(nbase):
        sum += Ci[i] * cheby(i,rango) * exp(-rango)
    return sum

# %%
xmin = 0
xmax = 20
npts = 300
rango = linspace(xmin,xmax,npts)

# %%
wave1s = psi(Ci,rango)

plot(rango, rango*wave1s)
